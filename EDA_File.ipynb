# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load dataset

df = pd.read_csv(
    r"C:\Users\deore\Downloads\archive (2)\books.csv",
    on_bad_lines="skip"
)

# %%
# inspect the dataset

df.head()
# Out:
#    bookID                                              title  \
# 0       1  Harry Potter and the Half-Blood Prince (Harry ...
# 1       2  Harry Potter and the Order of the Phoenix (Har...
# 2       4  Harry Potter and the Chamber of Secrets (Harry...
# 3       5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4       8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
#
#                       authors  average_rating        isbn         isbn13  \
# 0  J.K. Rowling/Mary GrandPré            4.57  0439785960  9780439785969
# 1  J.K. Rowling/Mary GrandPré            4.49  0439358078  9780439358071
# 2                J.K. Rowling            4.42  0439554896  9780439554893
# 3  J.K. Rowling/Mary GrandPré            4.56  043965548X  9780439655484
# 4  J.K. Rowling/Mary GrandPré            4.78  0439682584  9780439682589
#
#   language_code    num_pages  ratings_count  text_reviews_count  \
# 0           eng          652        2095690               27591
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (11123, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11123 entries, 0 to 11122
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   bookID              11123 non-null  int64
#  1   title               11123 non-null  object
#  2   authors             11123 non-null  object
#  3   average_rating      11123 non-null  float64
#  4   isbn                11123 non-null  object
#  5   isbn13              11123 non-null  int64
#  6   language_code       11123 non-null  object
#  7     num_pages         11123 non-null  int64
#  8   ratings_count       11123 non-null  int64
#  9   text_reviews_count  11123 non-null  int64
#  10  publication_date    11123 non-null  object
#  11  publisher           11123 non-null  object
# dtypes: float64(1), int64(5), object(6)
# memory usage: 1.0+ MB

# %%
df.describe()
# Out:
#              bookID  average_rating        isbn13     num_pages  \
# count  11123.000000    11123.000000  1.112300e+04  11123.000000
# mean   21310.856963        3.934075  9.759880e+12    336.405556
# std    13094.727252        0.350485  4.429758e+11    241.152626
# min        1.000000        0.000000  8.987060e+09      0.000000
# 25%    10277.500000        3.770000  9.780345e+12    192.000000
# 50%    20287.000000        3.960000  9.780582e+12    299.000000
# 75%    32104.500000        4.140000  9.780872e+12    416.000000
# max    45641.000000        5.000000  9.790008e+12   6576.000000
#
#        ratings_count  text_reviews_count
# count   1.112300e+04        11123.000000
# mean    1.794285e+04          542.048099
# std     1.124992e+05         2576.619589
# min     0.000000e+00            0.000000
# 25%     1.040000e+02            9.000000
# 50%     7.450000e+02           47.000000
# 75%     5.000500e+03          238.000000
# max     4.597666e+06        94265.000000

# %%
df.columns
# Out:
# Index(['bookID', 'title', 'authors', 'average_rating', 'isbn', 'isbn13',
#        'language_code', '  num_pages', 'ratings_count', 'text_reviews_count',
#        'publication_date', 'publisher'],
#       dtype='object')

# %%
# clean column names 

df.columns = df.columns.str.strip()
df.columns
# Out:
# Index(['bookID', 'title', 'authors', 'average_rating', 'isbn', 'isbn13',
#        'language_code', 'num_pages', 'ratings_count', 'text_reviews_count',
#        'publication_date', 'publisher'],
#       dtype='object')

# %%
# check missing values

df.isnull().sum()
# Out:
# bookID                0
# title                 0
# authors               0
# average_rating        0
# isbn                  0
# isbn13                0
# language_code         0
# num_pages             0
# ratings_count         0
# text_reviews_count    0
# publication_date      0
# publisher             0
# dtype: int64

# %%
# check missing values percentage in each column
(df.isnull().sum() / len(df) * 100).round(2)
# Out:
# bookID                0.0
# title                 0.0
# authors               0.0
# average_rating        0.0
# isbn                  0.0
# isbn13                0.0
# language_code         0.0
# num_pages             0.0
# ratings_count         0.0
# text_reviews_count    0.0
# publication_date      0.0
# publisher             0.0
# dtype: float64

# %%
df = df.copy()

# %% [markdown]
# # remove duplicate records

# %%
# count duplicates
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # title column

# %%
# count duplicate title in dataset
df["title"].duplicated().sum()
# Out:
# np.int64(775)

# %%
# print rows of duplicate title
df.loc[df["title"].duplicated(), "title"]
# Out:
# 10       The Hitchhiker's Guide to the Galaxy (Hitchhik...
# 24       The Lord of the Rings (The Lord of the Rings  ...
# 37                                          The Changeling
# 40                                         The Known World
# 41                                         The Known World
#                                ...
# 11075            Encuentro en el Ártico (Artemis Fowl  #2)
# 11076                      Artemis Fowl (Artemis Fowl  #1)
# 11078            The Subtle Knife (His Dark Materials  #2)
# 11080            The Subtle Knife (His Dark Materials  #2)
# 11096                                          On the Road
# Name: title, Length: 775, dtype: object

# %%
#  see all duplicate titles
df[df["title"].duplicated(keep=False)]
# Out:
#        bookID                                              title  \
# 0           1  Harry Potter and the Half-Blood Prince (Harry ...
# 2           4  Harry Potter and the Chamber of Secrets (Harry...
# 3           5  Harry Potter and the Prisoner of Azkaban (Harr...
# 9          14  The Hitchhiker's Guide to the Galaxy (Hitchhik...
# 10         16  The Hitchhiker's Guide to the Galaxy (Hitchhik...
# ...       ...                                                ...
# 11075   45463          Encuentro en el Ártico (Artemis Fowl  #2)
# 11076   45465                    Artemis Fowl (Artemis Fowl  #1)
# 11078   45479          The Subtle Knife (His Dark Materials  #2)
# 11080   45485          The Subtle Knife (His Dark Materials  #2)
# 11096   45536                                        On the Road
#
#                              authors  average_rating        isbn  \
# 0         J.K. Rowling/Mary GrandPré            4.57  0439785960
# ...

# %%
# remove duplicate rows and keep first
df = df.drop_duplicates("title",keep="first")

# %%
# check duplicates
df["title"].duplicated().sum()
# Out:
# np.int64(0)

# %%
# find the type of the title colum
df["title"].dtypes
# Out:
# dtype('O')

# %%
df = df.copy()

# %% [markdown]
# # authors column

# %%
# find type of author
df['authors'].dtypes
# Out:
# dtype('O')

# %%
df['authors'].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # rating column

# %%
# find type of rating 
df["average_rating"].dtypes
# Out:
# dtype('float64')

# %%
# check null values
df["average_rating"].isna().sum()
# Out:
# np.int64(0)

# %%
# check invalid ratings
i=df[
    (df["average_rating"] < 0) |
    (df["average_rating"] > 5)
]

i
# Out:
# Empty DataFrame
# Columns: [bookID, title, authors, average_rating, isbn, isbn13, language_code, num_pages, ratings_count, text_reviews_count, publication_date, publisher]
# Index: []

# %%
# find the min and max of the average_rating column
df["average_rating"].min(), df["average_rating"].max()
# Out:
# (0.0, 5.0)

# %%
df = df.copy()

# %% [markdown]
# # Publication date

# %%
# check the type of publication_date
df["publication_date"].dtypes
# Out:
# dtype('O')

# %%
# find the missing values
df["publication_date"].isna().sum()
# Out:
# np.int64(0)

# %%
df = df.copy()

# %%
# convert object to datetime format
df["publication_date"] = pd.to_datetime(
    df["publication_date"],
    errors = "coerce")

# %%
# create a separate year column
df["publication_year"] = df["publication_date"].dt.year

# %%
# check both columns
df[["publication_date","publication_year"]].head()
# Out:
#   publication_date  publication_year
# 0       2006-09-16            2006.0
# 1       2004-09-01            2004.0
# 2       2003-11-01            2003.0
# 3       2004-05-01            2004.0
# 4       2004-09-13            2004.0

# %%
# check type of publication_year
df["publication_year"].dtypes
# Out:
# dtype('float64')

# %%
# convert float to int
df["publication_year"]=df["publication_year"].astype("Int64")

# %%
# check the type
df["publication_year"].dtypes
# Out:
# Int64Dtype()

# %%
df["publication_year"].isnull().sum()
# Out:
# np.int64(2)

# %%
df = df.dropna(subset=["publication_year"])

# %%
df["publication_year"].dtypes
# Out:
# Int64Dtype()

# %%
df["publication_year"].isnull().sum()
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['bookID', 'title', 'authors', 'average_rating', 'isbn', 'isbn13',
#        'language_code', 'num_pages', 'ratings_count', 'text_reviews_count',
#        'publication_date', 'publisher', 'publication_year'],
#       dtype='object')

# %%
df =df.copy()

# %% [markdown]
# # author coloum

# %%
# find the type of author
df["authors"].dtypes
# Out:
# dtype('O')

# %%
# convert all values of authors coloumn into string type
df["authors"] = ( 
    df["authors"]
    .astype("string")
    .str.strip()
)

# %%
df["authors"].dtypes
# Out:
# string[python]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10346 entries, 0 to 11122
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   bookID              10346 non-null  int64
#  1   title               10346 non-null  object
#  2   authors             10346 non-null  string
#  3   average_rating      10346 non-null  float64
#  4   isbn                10346 non-null  object
#  5   isbn13              10346 non-null  int64
#  6   language_code       10346 non-null  object
#  7   num_pages           10346 non-null  int64
#  8   ratings_count       10346 non-null  int64
#  9   text_reviews_count  10346 non-null  int64
#  10  publication_date    10346 non-null  datetime64[ns]
#  11  publisher           10346 non-null  object
#  12  publication_year    10346 non-null  Int64
# dtypes: Int64(1), datetime64[ns](1), float64(1), int64(5), object(4), string(1)
# memory usage: 1.1+ MB

# %%
df["authors"].value_counts()
# Out:
# authors
# Rumiko Takahashi                                          39
# P.G. Wodehouse                                            39
# Orson Scott Card                                          33
# Piers Anthony                                             30
# Agatha Christie                                           30
#                                                           ..
# Hugh    Miller                                             1
# Lonely Planet/Sarah Johnstone/Steve Fallon                 1
# David Salo                                                 1
# Rough Guides/Jan Dodd/Mark Lewis/Ron Emmons                1
# William T. Vollmann/Larry McCaffery/Michael Hemmingson     1
# Name: count, Length: 6295, dtype: Int64

# %% [markdown]
# # text_reviews_count  column

# %%
df["text_reviews_count"].dtypes
# Out:
# dtype('int64')

# %%
df["text_reviews_count"].isna().sum()
# Out:
# np.int64(0)

# %%
df["text_reviews_count"].head()
# Out:
# 0    27591
# 1    29221
# 2      244
# 3    36325
# 4      164
# Name: text_reviews_count, dtype: int64

# %%
df = df.copy()

# %% [markdown]
# #
#
#
# rename colums and drop columns

# %%
df.columns
# Out:
# Index(['bookID', 'title', 'authors', 'average_rating', 'isbn', 'isbn13',
#        'language_code', 'num_pages', 'ratings_count', 'text_reviews_count',
#        'publication_date', 'publisher', 'publication_year'],
#       dtype='object')

# %%
df.rename(columns={"bookID":"Book_ID",
          "title":"Book_Title",
          "authors":"Authors",
          "average_rating":"Rating",
          "isbn":"ISBN-10",
          "isbn13":"ISBN-13",
          "num_pages":"Num_Of_Pages",
          "text_reviews_count":"Number_of_reviews",
          "publication_year":"Publication_year",
          "publisher":"Publisher",
          "language_code":"Language_Code",
          "ratings_count":"Ratings_Count",
                   
           
        
          },inplace = True)

# %%
df = df.copy()

# %%
df = df.copy()

# %% [markdown]
# # ISBN -10 column

# %%
df["ISBN-10"].duplicated().sum()
# Out:
# np.int64(0)

# %%
df["ISBN-10"].str.len().value_counts()
# Out:
# ISBN-10
# 10    10345
# 9         1
# Name: count, dtype: int64

# %%
df = df[df["ISBN-10"].notna()].copy()

df["ISBN-10"] = df["ISBN-10"].astype("string").str.strip()

df = df[df["ISBN-10"].str.len() == 10].copy()

# %%
df["ISBN-10"].str.len().value_counts()
# Out:
# ISBN-10
# 10    10345
# Name: count, dtype: Int64

# %% [markdown]
# # ISBN-13 colum

# %%
df["ISBN-10"].dtypes
# Out:
# string[python]

# %%
# convert string datatype
df["ISBN-13"] = df["ISBN-13"].astype("string")

# %%
# remove extra spaces
df["ISBN-13"] = df["ISBN-13"].astype("string").str.strip()

# %%
df["ISBN-13"].dtype
# Out:
# string[python]

# %%
df["ISBN-13"].str.len().value_counts()
# Out:
# ISBN-13
# 13    10320
# 12       14
# 11       10
# 10        1
# Name: count, dtype: Int64

# %%
df = df[df["ISBN-13"].notna()].copy()

df["ISBN-13"] = df["ISBN-13"].astype("string").str.strip()

df = df[df["ISBN-13"].str.len() == 13].copy()

# %%
df["ISBN-13"].str.len().value_counts()
# Out:
# ISBN-13
# 13    10320
# Name: count, dtype: Int64

# %%
df.head()
# Out:
#    Book_ID                                         Book_Title  \
# 0        1  Harry Potter and the Half-Blood Prince (Harry ...
# 1        2  Harry Potter and the Order of the Phoenix (Har...
# 2        4  Harry Potter and the Chamber of Secrets (Harry...
# 3        5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4        8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
#
#                       Authors  Rating     ISBN-10        ISBN-13  \
# 0  J.K. Rowling/Mary GrandPré    4.57  0439785960  9780439785969
# 1  J.K. Rowling/Mary GrandPré    4.49  0439358078  9780439358071
# 2                J.K. Rowling    4.42  0439554896  9780439554893
# 3  J.K. Rowling/Mary GrandPré    4.56  043965548X  9780439655484
# 4  J.K. Rowling/Mary GrandPré    4.78  0439682584  9780439682589
#
#   Language_Code  Num_Of_Pages  Ratings_Count  Number_of_reviews  \
# 0           eng           652        2095690              27591
# 1           eng           870        2153167              29221
# ...

# %%
df.columns
# Out:
# Index(['Book_ID', 'Book_Title', 'Authors', 'Rating', 'ISBN-10', 'ISBN-13',
#        'Language_Code', 'Num_Of_Pages', 'Ratings_Count', 'Number_of_reviews',
#        'publication_date', 'Publisher', 'Publication_year'],
#       dtype='object')

# %%
# arrange the columns in a logical order
df = df[
    [
        "Book_ID",
        "Book_Title",
        "Authors",
        "Rating",
        "Number_of_reviews",
        "Ratings_Count",
        "ISBN-10",
        "ISBN-13",
        "Num_Of_Pages",
        "Language_Code",
        "publication_date",
        "Publication_year",
        "Publisher"\
    ]
]

# %%
df.head()
# Out:
#    Book_ID                                         Book_Title  \
# 0        1  Harry Potter and the Half-Blood Prince (Harry ...
# 1        2  Harry Potter and the Order of the Phoenix (Har...
# 2        4  Harry Potter and the Chamber of Secrets (Harry...
# 3        5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4        8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
#
#                       Authors  Rating  Number_of_reviews  Ratings_Count  \
# 0  J.K. Rowling/Mary GrandPré    4.57              27591        2095690
# 1  J.K. Rowling/Mary GrandPré    4.49              29221        2153167
# 2                J.K. Rowling    4.42                244           6333
# 3  J.K. Rowling/Mary GrandPré    4.56              36325        2339585
# 4  J.K. Rowling/Mary GrandPré    4.78                164          41428
#
#       ISBN-10        ISBN-13  Num_Of_Pages Language_Code publication_date  \
# 0  0439785960  9780439785969           652           eng       2006-09-16
# ...

# %%
df = df.drop("publication_date",axis =1)

# %%
df.head()
# Out:
#    Book_ID                                         Book_Title  \
# 0        1  Harry Potter and the Half-Blood Prince (Harry ...
# 1        2  Harry Potter and the Order of the Phoenix (Har...
# 2        4  Harry Potter and the Chamber of Secrets (Harry...
# 3        5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4        8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
#
#                       Authors  Rating  Number_of_reviews  Ratings_Count  \
# 0  J.K. Rowling/Mary GrandPré    4.57              27591        2095690
# 1  J.K. Rowling/Mary GrandPré    4.49              29221        2153167
# 2                J.K. Rowling    4.42                244           6333
# 3  J.K. Rowling/Mary GrandPré    4.56              36325        2339585
# 4  J.K. Rowling/Mary GrandPré    4.78                164          41428
#
#       ISBN-10        ISBN-13  Num_Of_Pages Language_Code  Publication_year  \
# 0  0439785960  9780439785969           652           eng              2006
# ...

# %%
df = df.reset_index(drop=True)

# %%
df
# Out:
#        Book_ID                                         Book_Title  \
# 0            1  Harry Potter and the Half-Blood Prince (Harry ...
# 1            2  Harry Potter and the Order of the Phoenix (Har...
# 2            4  Harry Potter and the Chamber of Secrets (Harry...
# 3            5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4            8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
# ...        ...                                                ...
# 10315    45631   Expelled from Eden: A William T. Vollmann Reader
# 10316    45633                        You Bright and Risen Angels
# 10317    45634                    The Ice-Shirt (Seven Dreams #1)
# 10318    45639                                        Poor People
# 10319    45641                        Las aventuras de Tom Sawyer
#
#                                                  Authors  Rating  \
# 0                             J.K. Rowling/Mary GrandPré    4.57
# ...

# %%
df.columns
# Out:
# Index(['Book_ID', 'Book_Title', 'Authors', 'Rating', 'Number_of_reviews',
#        'Ratings_Count', 'ISBN-10', 'ISBN-13', 'Num_Of_Pages', 'Language_Code',
#        'Publication_year', 'Publisher'],
#       dtype='object')

# %% [markdown]
# # ISBN-13

# %%
df["ISBN-13"] = df["ISBN-13"].astype(str)

# %%
# clean spaces in text columns
text_cols = [
    "Book_Title",
    "Authors",
    "ISBN-10",
    "ISBN-13",
    "Language_Code",
    "Publisher"
]

for col in text_cols:
    df[col] = df[col].astype(str).str.strip()

# %%
# check the duplicate books

df["Book_Title"].duplicated().sum()
# Out:
# np.int64(0)

# %%
df["ISBN-13"].duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # check Rating

# %%
# shows normaly be in between 0 to 5
df["Rating"].min(),df["Rating"].max()
# Out:
# (0.0, 5.0)

# %%
# check unusual values
df[(df["Rating"] < 0) | (df["Rating"] > 5)]
# Out:
# Empty DataFrame
# Columns: [Book_ID, Book_Title, Authors, Rating, Number_of_reviews, Ratings_Count, ISBN-10, ISBN-13, Num_Of_Pages, Language_Code, Publication_year, Publisher]
# Index: []

# %% [markdown]
# # check Publication_year

# %%
df["Publication_year"].min(), df["Publication_year"].max()
# Out:
# (np.int64(1900), np.int64(2020))

# %%
df["Publication_year"].value_counts().sort_index()
# Out:
# Publication_year
# 1900    1
# 1913    1
# 1914    1
# 1919    1
# 1921    2
#        ..
# 2016    6
# 2017    7
# 2018    5
# 2019    6
# 2020    1
# Name: count, Length: 86, dtype: Int64

# %% [markdown]
# # check number of pages

# %%
df[df["Num_Of_Pages"] <= 0]
# Out:
#        Book_ID                                         Book_Title  \
# 282        955  The 5 Love Languages / The 5 Love Languages Jo...
# 775       2835                   The Tragedy of Pudd'nhead Wilson
# 970       3593  Murder by Moonlight & Other Mysteries (New Adv...
# 973       3599  The Unfortunate Tobacconist & Other Mysteries ...
# 1430      5362                         The Summons / The Brethren
# ...        ...                                                ...
# 9292     40378                  The Chessmen of Mars (Barsoom #5)
# 9450     41273                     Fine Lines (One-Eyed Mack  #6)
# 9855     43343  Stowaway and Milk Run: Two Unabridged Stories ...
# 10145    44748                        The Mask of the Enchantress
# 10278    45472  Treasury of American Tall Tales: Volume 1: Dav...
#
#                                                  Authors  Rating  \
# 282                                         Gary Chapman    4.70
# ...

# %%
df["Num_Of_Pages"].value_counts().loc[0]
# Out:
# np.int64(65)

# %%
import numpy as np

df["Num_Of_Pages"] = df["Num_Of_Pages"].replace(0, np.nan)

# %%
df["Num_Of_Pages"].isna().sum()
# Out:
# np.int64(65)

# %%
df=df.dropna(subset=["Num_Of_Pages"])

# %%
df["Num_Of_Pages"].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # check Number_of_reviews

# %%
df[df["Number_of_reviews"]<0]
# Out:
# Empty DataFrame
# Columns: [Book_ID, Book_Title, Authors, Rating, Number_of_reviews, Ratings_Count, ISBN-10, ISBN-13, Num_Of_Pages, Language_Code, Publication_year, Publisher]
# Index: []

# %%
df["Number_of_reviews"].describe()
# Out:
# count    10255.000000
# mean       533.361775
# std       2511.292343
# min          0.000000
# 25%          9.000000
# 50%         49.000000
# 75%        248.000000
# max      94265.000000
# Name: Number_of_reviews, dtype: float64

# %%
df["Number_of_reviews"].value_counts().loc[0]
# Out:
# np.int64(577)

# %%
df["Number_of_reviews"] = df["Number_of_reviews"].replace(0, np.nan)
# Out:
# C:\Users\deore\AppData\Local\Temp\ipykernel_11960\2630976911.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Number_of_reviews"] = df["Number_of_reviews"].replace(0, np.nan)

# %%
df["Number_of_reviews"].isna().sum()
# Out:
# np.int64(577)

# %%
df=df.dropna(subset=["Number_of_reviews"])

# %%
df['Number_of_reviews'].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # check Ratings_count

# %%
df["Ratings_Count"].value_counts().loc[0]
# Out:
# np.int64(2)

# %%
df["Ratings_Count"] = df["Ratings_Count"].replace(0, np.nan)

# %%
df["Ratings_Count"].isna().sum()
# Out:
# np.int64(2)

# %%
df=df.dropna(subset=["Ratings_Count"])

# %%
df["Ratings_Count"].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # stadardize Language_code

# %%
df["Language_Code"].value_counts()
# Out:
# Language_Code
# eng      7823
# en-US    1264
# en-GB     178
# spa       164
# fre        96
# ger        55
# jpn        32
# mul        17
# por        10
# grc         7
# en-CA       7
# ita         5
# enm         3
# zho         3
# lat         3
# rus         2
# glg         1
# swe         1
# nor         1
# ara         1
# msa         1
# nl          1
# tur         1
# Name: count, dtype: int64

# %%
df["Language_Code"].isna().sum()
# Out:
# np.int64(0)

# %%
df = df.copy()

# %%
# standardize Authors

# %%
df["Authors"] = df["Authors"].str.strip()

# %% [markdown]
# # standardize Publisher

# %%
print(df["Publisher"].value_counts())
# Out:
# Publisher
# Vintage                                    297
# Penguin Books                              225
# Penguin Classics                           146
# Mariner Books                              143
# Ballantine Books                           137
#                                           ...
# Tyndale Momentum                             1
# Houghton Mifflin Co. (Boston/NY)             1
# Inkling Books                                1
# AVA Publishing                               1
# Dodd Mead; 1st edition (September 1976)      1
# Name: count, Length: 2002, dtype: int64

# %%
print(df["Publisher"].value_counts().to_string())
# Out:
# Publisher
# Vintage                                                                297
# Penguin Books                                                          225
# Penguin Classics                                                       146
# Mariner Books                                                          143
# Ballantine Books                                                       137
# Bantam                                                                 105
# Harper Perennial                                                       104
# HarperCollins                                                          102
# Pocket Books                                                           100
# VIZ Media LLC                                                           88
# Berkley                                                                 84
# Del Rey                                                                 76
# ...

# %%
df[df["Publisher"].str.contains("Scholastic", case=False, na=False)]["Publisher"].value_counts()
# Out:
# Publisher
# Scholastic Paperbacks            54
# Scholastic                       28
# Scholastic Inc.                  11
# Scholastic  Inc.                  8
# Scholastic Press                  7
# Scholastic Books                  3
# Apple Paperbacks (Scholastic)     1
# Scholastic Inc                    1
# Hippo/Scholastic                  1
# Chicken House / Scholastic        1
# Scholastic Audio Books            1
# Scholastic Nonfiction             1
# Name: count, dtype: int64

# %%
df["Publisher"] = df["Publisher"].replace({
    "Scholastic  Inc.": "Scholastic Inc.",
    "Scholastic Inc": "Scholastic Inc."
})

# %%
df[df["Publisher"].str.contains("Scholastic", case=False, na=False)]["Publisher"].value_counts()
# Out:
# Publisher
# Scholastic Paperbacks            54
# Scholastic                       28
# Scholastic Inc.                  20
# Scholastic Press                  7
# Scholastic Books                  3
# Apple Paperbacks (Scholastic)     1
# Hippo/Scholastic                  1
# Chicken House / Scholastic        1
# Scholastic Audio Books            1
# Scholastic Nonfiction             1
# Name: count, dtype: int64

# %%
import pandas as pd

pd.set_option("display.max_rows", None
             

print(df["Publisher"].value_counts(dropna=False))
# Out:
#   Cell In[112], line 3
#     pd.set_option("display.max_rows", None
#                  ^
# SyntaxError: '(' was never closed

# %%
df["Publisher"] = df["Publisher"].str.replace(r"\s+", " ", regex=True).str.strip()

# %%
# Standardize whitespace
df["Publisher"] = (
    df["Publisher"]
    .str.replace(r"\s+", " ", regex=True)
    .str.strip()
)

# Fix obvious exact duplicates
df["Publisher"] = df["Publisher"].replace({
    "Scholastic Inc": "Scholastic Inc.",
})

# %%
import pandas as pd

pd.set_option("display.max_rows", None)
             

print(df["Publisher"].value_counts(dropna=False))

# %%
df["Publisher"] = (
    df["Publisher"]
    .str.replace(r"\s+", " ", regex=True)
    .str.strip()
)

# %%
publisher_map = {
    "Scholastic Inc": "Scholastic Inc.",
    "W.W. Norton & Company": "W. W. Norton & Company",
    "W.W. Norton": "W. W. Norton",
    "Simon Schuster": "Simon & Schuster",
    "Simon and Schuster": "Simon & Schuster",
    "Little Brown and Company": "Little Brown & Company",
    "Farrar Straus and Giroux": "Farrar, Straus and Giroux",
    "Farrar Straus Giroux": "Farrar, Straus and Giroux",
    "Farrar Straus & Giroux": "Farrar, Straus and Giroux",
    "Faber and Faber": "Faber & Faber",
    "Faber Faber": "Faber & Faber",
    "Harpercollins": "HarperCollins",
    "Harper Collins": "HarperCollins",
    "Harpperen": "Harperen",
    "Bantem Press": "Bantam Press",
    "Fawcett crest": "Fawcett Crest",
    "Readers Digest.": "Readers Digest",
    "Hamish hamilton": "Hamish Hamilton",
    "TusQuets": "Tusquets",
    "Tokyopop": "TokyoPop",
    "J'ai lu": "J'ai Lu",
    "University Of Chicago Press": "University of Chicago Press",
    "Thames Hudson": "Thames & Hudson",
    "Thames & Hudson": "Thames & Hudson",
}

# %%
df["Publisher"] = df["Publisher"].replace(publisher_map)

# %%
import numpy as np

df["Publisher"] = df["Publisher"].replace(
    ["Not Avail", "N/A", "NA", "Not Available", ""],
    np.nan
)

# %%
print(df["Publisher"].value_counts(dropna=False).to_string())

# %%
df["Publisher"].isna().sum()

# %%
df = df.dropna(subset=["Publisher"])

# %%
print(df["Publisher"].value_counts(dropna=False).to_string())

# %%
# 1. Remove extra spaces
df["Publisher"] = (
    df["Publisher"]
    .str.replace(r"\s+", " ", regex=True)
    .str.strip()
)

# %%
publisher_map = {
    "Scholastic Inc": "Scholastic Inc.",
    "W.W. Norton & Company": "W. W. Norton & Company",
    "W.W. Norton & Company (NY)": "W. W. Norton & Company",
    "W.W. Norton & Company (NYC)": "W. W. Norton & Company",
    "Bantem Press": "Bantam Press",
    "Random house": "Random House",
    "Harpercollins": "HarperCollins",
    "Harpercollins Childrens Books": "HarperCollins Children's Books",
    "TusQuets": "Tusquets",
    "Farrar Straus and Giroux": "Farrar, Straus and Giroux",
    "Farrar Straus and Giroux (NY)": "Farrar, Straus and Giroux",
    "Chatto Windus": "Chatto & Windus",
    "Chatto and Windus": "Chatto & Windus",
    "Inter Varsity Press": "InterVarsity Press",
    "Inter-Varsity Press": "InterVarsity Press",
}

# %%
df["Publisher"] = df["Publisher"].replace(publisher_map)

# %%
print(df["Publisher"].value_counts().to_string())

# %%
# 1. Remove extra spaces
df["Publisher"] = (
    df["Publisher"]
    .str.replace(r"\s+", " ", regex=True)
    .str.strip()
)

# 2. Fix clear spelling / formatting inconsistencies
publisher_map = {
    # W. W. Norton
    "W.W. Norton Company": "W. W. Norton Company",
    "W.W. Norton & Company": "W. W. Norton & Company",
    "W.W. Norton": "W. W. Norton",

    # Simon & Schuster
    "Simon Schuster": "Simon & Schuster",

    # Little Brown
    "Little Brown and Company": "Little Brown & Company",

    # Farrar
    "Farrar Straus and Giroux": "Farrar, Straus and Giroux",

    # Faber
    "Faber and Faber": "Faber & Faber",
    "Faber Faber": "Faber & Faber",

    # HarperCollins
    "Harpercollins": "HarperCollins",
    "Harper Collins": "HarperCollins",
    "Harpercollins Children's Books": "HarperCollins Children's Books",
    "HarperCollinsPublishers": "HarperCollins Publishers",

    # Scholastic
    "Scholastic Inc": "Scholastic Inc.",

    # Bantam
    "Bantem Press": "Bantam Press",

    # Other clear typos / formatting
    "TusQuets": "Tusquets",
    "Chatto Windus": "Chatto & Windus",
    "Chatto and Windus": "Chatto & Windus",
    "Inter Varsity Press": "InterVarsity Press",
    "Inter-Varsity Press": "InterVarsity Press",
    "Random house": "Random House",
    "Hamish hamilton": "Hamish Hamilton",
    "Readers Digest.": "Readers Digest",
    "Fawcett crest": "Fawcett Crest",
    "Harper Teen": "HarperTeen",
    "Tarcherperigee": "TarcherPerigee",
    "HarperPaperbacks": "Harper Paperbacks",
    "Hartorch": "HarperTorch",
    "B Books": "B Books",
    "Millenium": "Millennium",
    "Elloras Cave": "Ellora's Cave",
    "Serpents Tail": "Serpent's Tail",
    "Gingko Press": "Ginkgo Press",
    "Ballantine Books": "Ballantine Books",
}

df["Publisher"] = df["Publisher"].replace(publisher_map)

# %%
print(df["Publisher"].value_counts(dropna=False).to_string())

# %%
print("Unique publishers:", df["Publisher"].nunique())

# %%
df.info()

# %%
df.to_csv("clean_books2.csv", index=False)
